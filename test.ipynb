# %%
pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import glob

rawFile_path = "DATA/RAW/*.xlsx"
# Out:
# 0    South Dakota
# 1    South Dakota
# 2    South Dakota
# 3    South Dakota
# 4    South Dakota
# 5    South Dakota
# 6    South Dakota
# Name: State, dtype: object

# %%
# Drop the first row, set the new header, and reset the index in one go
dataframe.columns = dataframe.iloc[0]  # Set new header from the second row
dataframe = dataframe.drop(index=[0, 1]).reset_index(drop=True)  # Drop the first two rows and reset index



print(dataframe['State'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# Create the line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=dataframe, x='Year', y='Inclusion', marker='o')

# Customize the plot
plt.title('Net Occupancy Over Time')
plt.xlabel('Time')
plt.ylabel('Net Occupancy')
plt.xticks(rotation=45)  # Rotate x labels if needed
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
